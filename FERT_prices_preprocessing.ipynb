# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data_fert=pd.read_csv('Desktop\\empiezoitsolutions\\Data_Base_VDSA(Village_dynamics_Stataewise_AgriData)\\meso\\agritech.db\\fert_prices\\fert_prices.csv')

# %%
data_fert.head()
# Out:
#    State Code    State  District Code District Name  Year  Potassium  \
# 0           4  Haryana            177        Hissar  1966       1511
# 1           4  Haryana            177        Hissar  1967       1578
# 2           4  Haryana            177        Hissar  1968       1911
# 3           4  Haryana            177        Hissar  1969       2096
# 4           4  Haryana            177        Hissar  1970       2053
#
#    Magnesium  Calcium
# 0       1461      508
# 1       1844      655
# 2       1948      718
# 3       2795      833
# 4       3114      877

# %%
data_fert_cleaning=data_fert.copy()

# %%
data_fert_cleaning.head()
# Out:
#    State Code    State  District Code District Name  Year  Potassium  \
# 0           4  Haryana            177        Hissar  1966       1511
# 1           4  Haryana            177        Hissar  1967       1578
# 2           4  Haryana            177        Hissar  1968       1911
# 3           4  Haryana            177        Hissar  1969       2096
# 4           4  Haryana            177        Hissar  1970       2053
#
#    Magnesium  Calcium
# 0       1461      508
# 1       1844      655
# 2       1948      718
# 3       2795      833
# 4       3114      877

# %%
data_fert_cleaning.columns
# Out:
# Index(['State Code', 'State', 'District Code', 'District Name', 'Year',
#        'Potassium', 'Magnesium', 'Calcium'],
#       dtype='object')

# %%
data_fert_cleaning['State'].unique()
# Out:
# array(['Haryana', 'West Bengal', 'Uttar Pradesh', 'Tamil Nadu',
#        'Rajasthan', 'Punjab', 'Orissa', 'Maharashtra', 'Madhya Pradesh',
#        'Karnataka', 'Gujarat', 'Bihar', 'Andhra Pradesh'], dtype=object)

# %%
data_fert_cleaning['State'].nunique()
# Out:
# 13

# %% [markdown]
# There are 13 states

# %%
data_fert_cleaning.isna().sum()
# Out:
# State Code       0
# State            0
# District Code    0
# District Name    0
# Year             0
# Potassium        0
# Magnesium        0
# Calcium          0
# dtype: int64

# %% [markdown]
# It's clean data set

# %%
data_fert_cleaning.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8147 entries, 0 to 8146
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State Code     8147 non-null   int64
#  1   State          8147 non-null   object
#  2   District Code  8147 non-null   int64
#  3   District Name  8147 non-null   object
#  4   Year           8147 non-null   int64
#  5   Potassium      8147 non-null   int64
#  6   Magnesium      8147 non-null   int64
#  7   Calcium        8147 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 509.3+ KB

# %%
data_fert_cleaning.describe()
# Out:
#         State Code  District Code         Year    Potassium    Magnesium  \
# count  8147.000000    8147.000000  8147.000000  8147.000000  8147.000000
# mean      7.506690     231.852338  1980.001964  4048.359519  4095.498220
# std       3.732893     265.724084     8.367202  1566.957665  2050.204687
# min       1.000000       1.000000  1966.000000    -1.000000    -1.000000
# 25%       5.000000      71.000000  1973.000000  2280.000000  3114.000000
# 50%       7.000000     141.000000  1980.000000  4350.000000  4510.000000
# 75%      11.000000     219.000000  1987.000000  5110.000000  5860.000000
# max      13.000000     917.000000  1994.000000  7220.000000  7750.000000
#
#            Calcium
# count  8147.000000
# mean   1440.169265
# std     762.853515
# min      -1.000000
# 25%     877.000000
# 50%    1520.000000
# 75%    2085.000000
# max    2830.000000

# %%
plt.figure(figsize=(8, 4))
heatmap = sns.heatmap(data_fert_cleaning.corr(),linewidths=0, vmin=-1,annot=True,cmap="YlGnBu")
plt.show()

# %%
potassium_max=data_fert_cleaning.sort_values(by='Potassium',ascending=False)

# %%
potassium_max
# Out:
#       State Code           State  District Code     District Name  Year  \
# 8146           1  Andhra Pradesh             63          Adilabad  1994
# 3856           8          Orissa            708           Koraput  1994
# 8030           1  Andhra Pradesh             59          Nalgonda  1994
# 5277           6  Madhya Pradesh             18              Rewa  1994
# 4523           7     Maharashtra            112         Osmanabad  1994
# ...          ...             ...            ...               ...   ...
# 7360           2           Bihar            910  Santhal Paragana  1990
# 7359           2           Bihar            910  Santhal Paragana  1989
# 4030           7     Maharashtra             95            Bombay  1994
# 4029           7     Maharashtra             95            Bombay  1993
# 7370           2           Bihar            911          Shahabad  1971
#
#       Potassium  Magnesium  Calcium
# 8146       7220         -1       -1
# ...

# %%
magnesium_max=data_fert_cleaning.sort_values(by='Magnesium',ascending=False)

# %%
magnesium_max
# Out:
#       State Code           State  District Code District Name  Year  \
# 6086           5       Karnataka             66        Tumkur  1991
# 5970           6  Madhya Pradesh             42      Shajapur  1991
# 6840           3         Gujarat            130      Junagadh  1991
# 3824           8          Orissa            707      Keonjhar  1991
# 5419           6  Madhya Pradesh             23      Shivpuri  1991
# ...          ...             ...            ...           ...   ...
# 7564           2           Bihar            917     Singhbhum  1992
# 7565           2           Bihar            917     Singhbhum  1993
# 7566           2           Bihar            917     Singhbhum  1994
# 6205           5       Karnataka             70       Shimoga  1994
# 8146           1  Andhra Pradesh             63      Adilabad  1994
#
#       Potassium  Magnesium  Calcium
# 6086       6650       7750     2830
# 5970       6650       7750     2830
# 6840       6650       7750     2830
# ...

# %%
calcium_max=data_fert_cleaning.sort_values(by='Calcium',ascending=False)

# %%
calcium_max
# Out:
#       State Code           State  District Code  District Name  Year  \
# 1504          12   Uttar Pradesh            220         Ballia  1991
# 5738           6  Madhya Pradesh             34         Jhabua  1991
# 3737           8          Orissa            704      Dhenkanal  1991
# 6521           5       Karnataka             81  Uttar Kannada  1991
# 4781           6  Madhya Pradesh              1           Durg  1991
# ...          ...             ...            ...            ...   ...
# 7564           2           Bihar            917      Singhbhum  1992
# 7565           2           Bihar            917      Singhbhum  1993
# 7566           2           Bihar            917      Singhbhum  1994
# 6205           5       Karnataka             70        Shimoga  1994
# 8146           1  Andhra Pradesh             63       Adilabad  1994
#
#       Potassium  Magnesium  Calcium
# 1504       6650       7750     2830
# 5738       6650       7750     2830
# ...

# %%
overall_max=data_fert_cleaning.groupby(['State','District Name'])['Potassium','Magnesium','Calcium'].max().astype(int).reset_index()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_22748\1550550837.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   overall_max=data_fert_cleaning.groupby(['State','District Name'])['Potassium','Magnesium','Calcium'].max().astype(int).reset_index()

# %%
overall_max.sort_values(by=['Potassium','Magnesium','Calcium'],ascending=[False,False,False],inplace=True)

# %%
overall_max.head()
# Out:
#             State  District Name  Potassium  Magnesium  Calcium
# 0  Andhra Pradesh       Adilabad       7220       7750     2830
# 1  Andhra Pradesh      Anantapur       7220       7750     2830
# 2  Andhra Pradesh       Chittoor       7220       7750     2830
# 3  Andhra Pradesh       Cuddapah       7220       7750     2830
# 4  Andhra Pradesh  East Godavari       7220       7750     2830

# %%
data_fert_cleaning.hist(figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'State Code'}>,
#         <AxesSubplot:title={'center':'District Code'}>],
#        [<AxesSubplot:title={'center':'Year'}>,
#         <AxesSubplot:title={'center':'Potassium'}>],
#        [<AxesSubplot:title={'center':'Magnesium'}>,
#         <AxesSubplot:title={'center':'Calcium'}>]], dtype=object)

# %%
sns.distplot(data_fert_cleaning.Potassium)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Potassium', ylabel='Density'>

# %%
sns.distplot(data_fert_cleaning.Magnesium)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Magnesium', ylabel='Density'>

# %%
sns.distplot(data_fert_cleaning.Calcium)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Calcium', ylabel='Density'>

# %%
ml_fert_prices=data_fert_cleaning[['State Code', 'District Code', 'Year',
       'Potassium', 'Magnesium', 'Calcium']]

# %%
ml_fert_prices
# Out:
#       State Code  District Code  Year  Potassium  Magnesium  Calcium
# 0              4            177  1966       1511       1461      508
# 1              4            177  1967       1578       1844      655
# 2              4            177  1968       1911       1948      718
# 3              4            177  1969       2096       2795      833
# 4              4            177  1970       2053       3114      877
# ...          ...            ...   ...        ...        ...      ...
# 8142           1             63  1990       5110       5940     2170
# 8143           1             63  1991       6650       7750     2830
# 8144           1             63  1992       6000         -1       -1
# 8145           1             63  1993       6000         -1       -1
# 8146           1             63  1994       7220         -1       -1
#
# [8147 rows x 6 columns]
